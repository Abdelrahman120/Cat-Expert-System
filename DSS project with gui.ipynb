# %%
from experta import *
from tkinter import *
class Symptom(Fact):
    """Stores information about symptoms"""
    pass

class CatExpertSystem(KnowledgeEngine):
	@DefFacts()
	def inti(self):
		gui_form1 = Tk()
		gui_form1.configure(bg = 'white') 
		gui_form1.title("Diagnosis of cat diseases expert system")
		gui_form1.geometry("950x450")
		lb0 = Label(gui_form1,text=" welcome to our Medical cat expert system \n enter the symptom which your cat has using -yes- or -no- :",bg="#008080", fg="white",width="800")
		lb0.pack()
###############################################################################
		lb1 = Label(gui_form1,text="vomiting",bg = 'white')
		en1 = Entry(gui_form1)
		lb1.place(x= 10, y = 50)
		en1.place(x = 10, y = 75)
###############################################################################
		lb2 = Label(gui_form1,text="diarrhea",bg = 'white')
		en2 = Entry(gui_form1)
		lb2.place(x = 200, y = 50)
		en2.place(x = 200, y = 75)
###############################################################################
		lb3 = Label(gui_form1,text="lethargy",bg = 'white')
		en3 = Entry(gui_form1)
		lb3.place(x = 390, y = 50)
		en3.place(x = 390, y = 75)
###############################################################################
		lb4 = Label(gui_form1,text="sneezing",bg = 'white')
		en4 = Entry(gui_form1)
		lb4.place(x = 580, y = 50)
		en4.place(x = 580, y = 75)
###############################################################################
		lb5 = Label(gui_form1,text="runny_nose",bg = 'white')
		en5 = Entry(gui_form1)
		lb5.place(x = 770, y = 50 )
		en5.place(x = 770, y = 75)
###############################################################################
		lb6 = Label(gui_form1,text="conjunctivitis",bg = 'white')
		en6 = Entry(gui_form1)
		lb6.place(x = 960, y = 50)
		en6.place(x = 960, y = 75)
###############################################################################
		lb7 = Label(gui_form1,text="anorexia",bg = 'white')
		en7 = Entry(gui_form1)
		lb7.place(x = 1150, y = 50)
		en7.place(x = 1150, y = 75)
###############################################################################
		lb8 = Label(gui_form1,text="dehydration",bg = 'white')
		en8 = Entry(gui_form1)
		lb8.place(x = 10, y = 200)
		en8.place(x = 10, y = 225)
###############################################################################
		lb9 = Label(gui_form1,text="coughing",bg = 'white')
		en9 = Entry(gui_form1)
		lb9.place(x= 200, y = 200)
		en9.place(x = 200, y = 225)
###############################################################################
		lb10 = Label(gui_form1,text="fever",bg = 'white')
		en10 = Entry(gui_form1)
		lb10.place(x = 390, y = 200)
		en10.place(x = 390, y = 225)
###############################################################################
		lb11 = Label(gui_form1,text="itching",bg = 'white')
		en11= Entry(gui_form1)
		lb11.place(x = 580, y =200)
		en11.place(x = 580, y = 225)
###############################################################################
		lb12 = Label(gui_form1,text="hair_loss",bg = 'white')
		en12 = Entry(gui_form1)
		lb12.place(x = 770, y = 200)
		en12.place(x = 770, y = 225)
###############################################################################
		lb13 = Label(gui_form1,text="crusty_skin",bg = 'white')
		en13 = Entry(gui_form1)
		lb13.place(x = 960, y =200)
		en13.place(x = 960, y = 225)
###############################################################################
		lb14 = Label(gui_form1,text="sudden_weight_loss",bg = 'white')
		en14 = Entry(gui_form1)
		lb14.place(x = 1150, y = 200)
		en14.place(x = 1150, y = 225)
###############################################################################
		lb15 = Label(gui_form1,text="increased_thirst",bg = 'white')
		en15 = Entry(gui_form1)
		lb15.place(x = 10, y = 300)
		en15.place(x = 10, y = 330)
###############################################################################
		lb16 = Label(gui_form1,text="increased_urination",bg = 'white')
		en16 = Entry(gui_form1)
		lb16.place(x = 200, y = 300)
		en16.place(x = 200, y = 330)
###############################################################################
		lb17 = Label(gui_form1,text="labored_breathing",bg = 'white')
		en17 = Entry(gui_form1)
		lb17.place(x = 390, y = 300)
		en17.place(x = 390, y = 330)
		def get_values():
			#lb2["text"] = en2.get()
			self.declare(Fact(vomiting=en1.get()))
			self.declare(Fact(diarrhea=en2.get()))
			self.declare(Fact(lethargy=en3.get()))
			self.declare(Fact(sneezing=en4.get()))
			self.declare(Fact(runny_nose=en5.get()))
			self.declare(Fact(conjunctivitis=en6.get()))
			self.declare(Fact(anorexia=en7.get()))
			self.declare(Fact(dehydration=en8.get()))
			self.declare(Fact(coughing=en9.get()))
			self.declare(Fact(fever=en10.get()))
			self.declare(Fact(itching=en11.get()))
			self.declare(Fact(hair_loss=en12.get()))
			self.declare(Fact(crusty_skin=en13.get()))
			self.declare(Fact(sudden_weight_loss=en14.get()))
			self.declare(Fact(increased_thirst=en15.get()))
			self.declare(Fact(increased_urination=en16.get()))
			self.declare(Fact(labored_breathing=en17.get()))
#############################################################################
		btn = Button(gui_form1,command=get_values,text="get_values",bg="#008080", fg="#fff")
		btn.place(x = 600, y =400)    
		gui_form1.mainloop()
		yield Fact(action="make diagnosis")
#############################################################################
####################################################################################################################      
        
	@Rule(Fact(action='make diagnosis'),Fact(vomiting='yes'), Fact(diarrhea='yes'), Fact(lethargy='yes'),
          Fact(sneezing='no'),Fact(runny_nose='no'), Fact(conjunctivitis='no')
          ,Fact(anorexia='no'),Fact(dehydration='no'),Fact (coughing='no'),
          Fact(fever='no'), Fact(itching='no'), Fact(hair_loss='no'),
          Fact(crusty_skin='no'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='no'))
	def rule_gastroenteritis_cat(self):
		self.declare(Fact(disease='gastroenteritis'))

	@Rule(Fact(action='make diagnosis'),Fact(vomiting='no'), Fact(diarrhea='no'), Fact(lethargy='no')
          ,Fact(sneezing='yes'), Fact(runny_nose='yes'), Fact(conjunctivitis='yes')
          ,Fact(anorexia='no'), Fact(dehydration='no'), Fact(coughing='no'),
          Fact(fever='no'), Fact(itching='no'), Fact(hair_loss='no'),
          Fact(crusty_skin='no'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='no'))
	def rule_feline_viral_rhinotracheitis(self):
		self.declare(Fact(disease='feline viral rhinotracheitis'))

	@Rule(Fact(action='make diagnosis'),Fact(vomiting='no'), Fact(diarrhea='no'), Fact(lethargy='yes')
          ,Fact(sneezing='no'), Fact(runny_nose='no'), Fact(conjunctivitis='no')
          ,Fact(anorexia='yes'), Fact(dehydration='yes'), Fact(coughing='no'),
          Fact(fever='no'), Fact(itching='no'), Fact(hair_loss='no'),
          Fact(crusty_skin='no'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='no'))
	def rule_feline_panleukopenia(self):
		self.declare(Fact(disease='feline panleukopenia'))

	@Rule(Fact(action='make diagnosis'),Fact(vomiting='no'), Fact(diarrhea='no'), Fact(lethargy='no')
          ,Fact(sneezing='yes'), Fact(runny_nose='no'), Fact(conjunctivitis='no')
          ,Fact(anorexia='no'), Fact(dehydration='no'), Fact(coughing='yes'),
          Fact(fever='yes'), Fact(itching='no'), Fact(hair_loss='no'),
          Fact(crusty_skin='no'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='no'))
	def rule_feline_infectious_peritonitis(self):
		self.declare(Fact(disease='feline infectious peritonitis'))

	@Rule(Fact(action='make diagnosis'),Fact(vomiting='no'), Fact(diarrhea='no'), Fact(lethargy='no')
          ,Fact(sneezing='no'), Fact(runny_nose='no'), Fact(conjunctivitis='no')
          ,Fact(anorexia='no'), Fact(dehydration='no'), Fact(coughing='no'),
          Fact(fever='no'),Fact(itching='yes'), Fact(hair_loss='yes'),
          Fact(crusty_skin='yes'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='no'))
	def rule_flea_allergy_dermatitis(self):
		self.declare(Fact(disease='flea allergy dermatitis'))

	@Rule(Fact(action='make diagnosis'),Fact(vomiting='no'), Fact(diarrhea='no'), Fact(lethargy='no')
          ,Fact(sneezing='no'), Fact(runny_nose='no'), Fact(conjunctivitis='no')
          ,Fact(anorexia='no'), Fact(dehydration='no'), Fact(coughing='no'),
          Fact(fever='no'), Fact(itching='no'), Fact(hair_loss='no'),
          Fact(crusty_skin='no'), Fact(sudden_weight_loss='yes'), Fact(increased_thirst='yes'),
          Fact(increased_urination='yes'), Fact(labored_breathing='no'))
	def rule_feline_diabetes(self):
		self.declare(Fact(disease='feline diabetes'))

	@Rule(Fact(action='make diagnosis'),Fact(vomiting='no'), Fact(diarrhea='no'), Fact(lethargy='yes')
          ,Fact(sneezing='no'), Fact(runny_nose='no'), Fact(conjunctivitis='no')
          ,Fact(anorexia='no'), Fact(dehydration='no'), Fact(coughing='yes'),
          Fact(fever='no'), Fact(itching='no'), Fact(hair_loss='no'),
          Fact(crusty_skin='no'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='yes'))
	def rule_feline_asthma(self):
		self.declare(Fact(disease='feline asthma'))
    
	@Rule(Fact(action='make diagnosis'),Fact(vomiting='no'), Fact(diarrhea='no'), Fact(lethargy='no')
          ,Fact(sneezing='yes'), Fact(runny_nose='yes'), Fact(conjunctivitis='yes')
          ,Fact(anorexia='no'), Fact(dehydration='no'), Fact(coughing='yes'),
          Fact(fever='no'), Fact(itching='no'), Fact(hair_loss='no'),
          Fact(crusty_skin='no'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='no'))
	def diagnosis_feline_upper_respiratory_infection(self):
		self.declare(Fact(disease='Feline Upper Respiratory Infection'))

	@Rule(Fact(action='make diagnosis'),Fact(vomiting='yes'), Fact(diarrhea='yes'), Fact(lethargy='yes')
          ,Fact(sneezing='no'), Fact(runny_nose='no'), Fact(conjunctivitis='no')
          ,Fact(anorexia='yes'), Fact(dehydration='no'), Fact(coughing='no'),
          Fact(fever='no'), Fact(itching='no'), Fact(hair_loss='no'),
          Fact(crusty_skin='no'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='no'))
	def diagnosis_feline_infectious_peritonitis(self):
		self.declare(Fact(disease='Feline Infectious Peritonitis'))

	@Rule(Fact(action='make diagnosis'),Fact(vomiting='yes'), Fact(diarrhea='yes'), Fact(lethargy='yes')
          ,Fact(sneezing='no'), Fact(runny_nose='no'), Fact(conjunctivitis='no')
          ,Fact(anorexia='no'), Fact(dehydration='yes'), Fact(coughing='no'),
          Fact(fever='no'), Fact(itching='no'), Fact(hair_loss='no'),
          Fact(crusty_skin='no'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='no'))
	def diagnosis_feline_panleukopenia(self):
		self.declare(Fact(disease='Feline Panleukopenia'))

	@Rule(Fact(action='make diagnosis'),Fact(vomiting='no'), Fact(diarrhea='no'), Fact(lethargy='no')
          ,Fact(sneezing='no'), Fact(runny_nose='no'), Fact(conjunctivitis='no')
          ,Fact(anorexia='no'), Fact(dehydration='no'), Fact(coughing='no'),
          Fact(fever='no'), Fact(itching='yes'), Fact(hair_loss='yes'),
          Fact(crusty_skin='yes'), Fact(sudden_weight_loss='yes'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='no'))
	def diagnosis_feline_immunodeficiency_virus(self):
		self.declare(Fact(disease='Feline Immunodeficiency Virus'))

	@Rule(Fact(action='make diagnosis'),Fact(vomiting='no'), Fact(diarrhea='no'), Fact(lethargy='yes')
          ,Fact(sneezing='no'), Fact(runny_nose='no'), Fact(conjunctivitis='no')
          ,Fact(anorexia='no'), Fact(dehydration='no'), Fact(coughing='no'),
          Fact(fever='no'), Fact(itching='no'), Fact(hair_loss='no'),
          Fact(crusty_skin='no'), Fact(sudden_weight_loss='yes'), Fact(increased_thirst='yes'),
          Fact(increased_urination='yes'), Fact(labored_breathing='no'))
	def diagnosis_feline_diabetes(self):
		self.declare(Fact(disease='Feline Diabetes'))

	@Rule(Fact(action='make diagnosis'),Fact(vomiting='no'), Fact(diarrhea='no'), Fact(lethargy='yes')
          ,Fact(sneezing='yes'), Fact(runny_nose='no'), Fact(conjunctivitis='no')
          ,Fact(anorexia='no'), Fact(dehydration='no'), Fact(coughing='yes'),
          Fact(fever='no'), Fact(itching='no'), Fact(hair_loss='no'),
          Fact(crusty_skin='no'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='yes'))
	def diagnosis_feline_asthma(self):
		self.declare(Fact(disease='Feline Asthma'))
	@Rule(Fact(action='make diagnosis'), Fact(vomiting='no'), Fact(diarrhea='no'), Fact(lethargy='no'),
      Fact(sneezing='yes'), Fact(runny_nose='yes'), Fact(conjunctivitis='no'),
      Fact(anorexia='no'), Fact(dehydration='no'), Fact(coughing='no'),
      Fact(fever='yes'), Fact(itching='no'), Fact(hair_loss='no'),
      Fact(crusty_skin='no'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
      Fact(increased_urination='no'), Fact(labored_breathing='no'))
	def rule_feline_calicivirus(self):
		self.declare(Fact(disease='feline calicivirus'))

	@Rule(Fact(action='make diagnosis'), Fact(vomiting='no'), Fact(diarrhea='no'), Fact(lethargy='no'),
          Fact(sneezing='no'), Fact(runny_nose='no'), Fact(conjunctivitis='no'),
          Fact(anorexia='yes'), Fact(dehydration='no'), Fact(coughing='no'),
          Fact(fever='no'), Fact(itching='no'), Fact(hair_loss='yes'),
          Fact(crusty_skin='yes'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='no'))
	def rule_ringworm(self):
		self.declare(Fact(disease='ringworm'))

	@Rule(Fact(action='make diagnosis'), Fact(vomiting='no'), Fact(diarrhea='yes'), Fact(lethargy='yes'),
          Fact(sneezing='no'), Fact(runny_nose='no'), Fact(conjunctivitis='no'),
          Fact(anorexia='yes'), Fact(dehydration='yes'), Fact(coughing='no'),
          Fact(fever='no'), Fact(itching='no'), Fact(hair_loss='no'),
          Fact(crusty_skin='no'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='no'))
	def rule_feline_enteritis(self):
		self.declare(Fact(disease='feline enteritis'))
	@Rule(Fact(action='make diagnosis'), Fact(vomiting='no'), Fact(diarrhea='no'), Fact(lethargy='no'),
          Fact(sneezing='no'), Fact(runny_nose='no'), Fact(conjunctivitis='no'),
          Fact(anorexia='no'), Fact(dehydration='no'), Fact(coughing='no'),
          Fact(fever='no'), Fact(itching='no'), Fact(hair_loss='no'),
          Fact(crusty_skin='no'), Fact(sudden_weight_loss='no'), Fact(increased_thirst='no'),
          Fact(increased_urination='no'), Fact(labored_breathing='no'))
	def rule_feline_enteritis(self):
		self.declare(Fact(disease='your cat has no disease'))
	@Rule(Fact(action='make diagnosis'), Fact(vomiting='yes'), Fact(diarrhea='yes'), Fact(lethargy='yes'),
          Fact(sneezing='yes'), Fact(runny_nose='yes'), Fact(conjunctivitis='yes'),
          Fact(anorexia='yes'), Fact(dehydration='yes'), Fact(coughing='yes'),
          Fact(fever='yes'), Fact(itching='yes'), Fact(hair_loss='yes'),
          Fact(crusty_skin='yes'), Fact(sudden_weight_loss='yes'), Fact(increased_thirst='yes'),
          Fact(increased_urination='yes'), Fact(labored_breathing='yes'))
	def rule_feline_enteritis(self):
		self.declare(Fact(disease='that is impossible ! you should take your cat to doctor'))

        
	@Rule(Fact(action="make diagnosis"),Fact(disease=MATCH.disease))
	def result(self,disease):
		print("")
		id_disease = disease
		gui_form2 = Tk()
		gui_form2.configure(bg = 'white')
		gui_form2.title("Diagnosis of cat diseases expert system answer")
		gui_form2.geometry("600x300")
		lb0 = Label(gui_form2,text="the most probalple diesease is",bg="#008080", fg="#fff",width="800")
		lb0.pack()
		var = StringVar()
		var.set(id_disease)
		lb1 = Label(gui_form2, textvariable = var,bg="#008080", fg="#fff",width="800")
		lb1.pack()
		#print("The most probable disease that you have is %s\n" %(id_disease))
		gui_form2.mainloop()

engine = CatExpertSystem()
while(1):
    engine.reset()  # Prepare the engine for the execution.
    engine.run()  # Run it!
    print("Would you like to diagnose some other symptoms?")
    if input() == "no":
        break;
# Out:
# WARNING:experta.watchers.ENGINE:Declaring fact before reset()
# Would you like to diagnose some other symptoms?
# no
